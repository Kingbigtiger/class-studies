# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ecommerce = pd.DataFrame()
ecommerce['spending'] = np.random.normal(5, 25, 100)

# Plot a histogram.
plt.hist(ecommerce['spending'])
plt.show()

# %%
# Plot a histogram for ecommerce random.normal distribution.
plt.hist(ecommerce['spending'], color='c')

# Add a vertical line at the mean.
plt.axvline(ecommerce['spending'].mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
plt.axvline(ecommerce['spending'].mean() + ecommerce['spending'].std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean.
plt.axvline(ecommerce['spending'].mean()-ecommerce['spending'].std(), color='b', linestyle='dashed', linewidth=2) 
#
# Print the histogram.
plt.show()

# %% [markdown]
# This Distribution is useful but the there is still a fair amount of data a skew outside the mean

# %%
ecommerce1 = pd.DataFrame()
ecommerce1['spending'] = np.random.chisquare(5, 100)

# Plot a histogram.
plt.hist(ecommerce1['spending'])
plt.show()

# %%
# Plot a histogram for ecommerce random.chisquare distribution.
plt.hist(ecommerce1['spending'], color='c')

# Add a vertical line at the mean.
plt.axvline(ecommerce1['spending'].mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
plt.axvline(ecommerce1['spending'].mean() + ecommerce1['spending'].std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean.
plt.axvline(ecommerce1['spending'].mean()-ecommerce1['spending'].std(), color='b', linestyle='dashed', linewidth=2) 
#
# Print the histogram.
plt.show()

# %% [markdown]
# This is distribution is not very useful as the mean is skewed to right of zero

# %%
ecommerce2 = pd.DataFrame()
ecommerce2['spending'] = np.random.standard_cauchy(100)

# Plot a histogram.
plt.hist(ecommerce2['spending'])
plt.show()

# %%
# Plot a histogram for ecommerce Standard_cauchy distribution.
plt.hist(ecommerce2['spending'], color='c')

# Add a vertical line at the mean.
plt.axvline(ecommerce2['spending'].mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
plt.axvline(ecommerce2['spending'].mean() + ecommerce2['spending'].std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean.
plt.axvline(ecommerce2['spending'].mean()-ecommerce2['spending'].std(), color='b', linestyle='dashed', linewidth=2) 
#
# Print the histogram.
plt.show()

# %% [markdown]
# This would be my first choice as all the data is range of the mean with very little outside the mean

# %%
ecommerce3 = pd.DataFrame()
ecommerce3['spending'] = np.random.standard_normal(100)

# Plot a histogram.
plt.hist(ecommerce3['spending'])
plt.show()

# %%
# Plot a histogram for ecommerce random.standard_normal distribution.
plt.hist(ecommerce3['spending'], color='c')

# Add a vertical line at the mean.
plt.axvline(ecommerce3['spending'].mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
plt.axvline(ecommerce3['spending'].mean() + ecommerce3['spending'].std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean.
plt.axvline(ecommerce3['spending'].mean()-ecommerce3['spending'].std(), color='b', linestyle='dashed', linewidth=2) 
#
# Print the histogram.
plt.show()

# %% [markdown]
# The standard_normal is pretty close to a second choice or Alternative Choice as the bulk of the data falls into a narrower scope.

# %%
ecommerce4 = pd.DataFrame()
ecommerce4['spending'] = np.random.standard_exponential(100)

# Plot a histogram.
plt.hist(ecommerce4['spending'])
plt.show()

# %%
# Plot a histogram for ecommerce random.standard_exponential distribution.
plt.hist(ecommerce4['spending'], color='c')

# Add a vertical line at the mean.
plt.axvline(ecommerce4['spending'].mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
plt.axvline(ecommerce4['spending'].mean() + ecommerce4['spending'].std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean.
plt.axvline(ecommerce4['spending'].mean()-ecommerce4['spending'].std(), color='b', linestyle='dashed', linewidth=2) 
#
# Print the histogram.
plt.show()

# %% [markdown]
# This distrubution is skewed too heavily to the right of zero not taking into account data below zero. Not useful for this excercise

# %% [markdown]
# Additional Exercise

# %%
import numpy as np
import matplotlib.pyplot as plt
var1 = np.random.normal(5,.5, 100)
var2 = np.random.normal(10,1, 100)
var3 = var1+var2

mean = np.mean(var3)
sd = np.std(var3)

plt.hist(var3)
plt.axvline(x=mean,color='black')
plt.axvline(x=mean+sd, color='red')
plt.axvline(x=mean-sd, color='red')
plt.show()
print('Results will vary depending on random seed.  In general, stats should show some skew.')
# Out:
# Results will vary depending on random seed.  In general, stats should show some skew.

# %% [markdown]
# The 3rd variable falls very nicely in the mean as the data is very close between the two axial lines.
